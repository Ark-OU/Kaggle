# %%
from jupyterthemes import jtplot
jtplot.style(theme='monokai') 
import gdal
import numpy as np
import re
import os, io, re

# import image
train_path = './train_crowns/train_crowns/'
test_path = "./test_crowns/"
# filename を全て入れる
train_files = []
test_files = []
for filename in os.listdir(train_path):
    if os.path.isfile(os.path.join(train_path, filename)):
        train_files.append(filename)
for filename in os.listdir(test_path):
    if os.path.isfile(os.path.join(test_path, filename)):
        test_files.append(filename)

# .tifのファイルを選んで入れる
train_img = []
test_img= []
for name in train_files:
    if re.search(r"(.tif)$", name):
        train_img.append(name)
for name in test_files:
    if re.search(r"(.tif)$", name):
        test_img.append(name)
# print(img_files)

# %%
train_height = []
train_DBH = []
train_index = []
test_height = []
test_index = []

for imgfile in train_files:
    image = gdal.Open("C:/Users/owner/Kaggle/GE_Kaggle01/train_crowns/train_crowns/"+imgfile, gdal.GA_ReadOnly)
    a = np.array([image.GetRasterBand(i + 1).ReadAsArray() for i in range(image.RasterCount)])
    train_height.append(a[0<a].mean())
#     print(a[a>0].mean())
    file = os.path.splitext(imgfile)[0]
    file_split = [i for i in file.split("_")]
    train_index.append(file_split[0])
    train_DBH.append(float(file_split[3]))
#     print(float(file_split[3]))
    
for imgfile in test_files:
    image = gdal.Open("C:/Users/owner/Kaggle/GE_Kaggle01/test_crowns/"+imgfile, gdal.GA_ReadOnly)
    a = np.array([image.GetRasterBand(i + 1).ReadAsArray() for i in range(image.RasterCount)])
    test_height.append(a[a>0].mean())
#     print(a[a>0].mean())
    file = os.path.basename(imgfile)
    file_split = [i for i in file.split("_")]
    test_index.append(file_split[0])
#     print(file_split[0])

# %%
import pandas as pd
index = pd.Index(train_index)
d = {"Height": train_height}
train = pd.DataFrame(data=d, index=index)
# print(train)
target = pd.DataFrame({"DBH": train_DBH}, index=index)
# print(target)
test = pd.DataFrame(data={"Height": test_height}, index=pd.Index(test_index))

# %%
tmp = pd.DataFrame({"Height": train_height, "DBH": train_DBH}, index=index)
# print(tmp)
import matplotlib.pyplot as plt
x = np.log(tmp["DBH"])
y = np.log(tmp["Height"])
plt.scatter(x,y)
plt.xlabel("DBH [cm]")
plt.ylabel("Height [m]")
plt.axis([0,5,0,5])
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, Y_train, X_target, Y_target = train_test_split(np.log(train), np.log(target), random_state=0)
# print(X_train.shape, Y_train.shape, X_valid.shape, Y_valid.shape)

# %%
import xgboost as xgb
dtrain = xgb.DMatrix(X_train, label=X_target)
dvalid = xgb.DMatrix(Y_train, label=Y_target)
num_round = 500
evallist = [(dvalid, "eval"), (dtrain, "train")]
evals_result = {}
param = {
    "max_depth": 3,
    "eta": 0.01,
    "objective": "reg:squarederror",
}
bst = xgb.train(
                        param, dtrain,
                        num_round,
                        evallist,
                        evals_result=evals_result,
                        # 一定ラウンド回しても改善が見込めない場合は学習を打ち切る
                        early_stopping_rounds=1000
)
# Out:
# [0]	eval-rmse:3.06664	train-rmse:3.14252
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
# Will train until train-rmse hasn't improved in 1000 rounds.
# [1]	eval-rmse:3.03601	train-rmse:3.11199
# [2]	eval-rmse:3.00569	train-rmse:3.08177
# [3]	eval-rmse:2.97568	train-rmse:3.05185
# [4]	eval-rmse:2.94596	train-rmse:3.02223
# [5]	eval-rmse:2.91654	train-rmse:2.99291
# [6]	eval-rmse:2.88741	train-rmse:2.96388
# [7]	eval-rmse:2.85857	train-rmse:2.93514
# [8]	eval-rmse:2.83002	train-rmse:2.90669
# [9]	eval-rmse:2.80176	train-rmse:2.87853
# [10]	eval-rmse:2.77378	train-rmse:2.85065
# [11]	eval-rmse:2.74607	train-rmse:2.82305
# [12]	eval-rmse:2.71865	train-rmse:2.79573
# [13]	eval-rmse:2.6915	train-rmse:2.76869
# [14]	eval-rmse:2.66461	train-rmse:2.74191
# [15]	eval-rmse:2.638	train-rmse:2.71541
# [16]	eval-rmse:2.61166	train-rmse:2.68917
# [17]	eval-rmse:2.58557	train-rmse:2.66319
# [18]	eval-rmse:2.55975	train-rmse:2.63748
# [19]	eval-rmse:2.53419	train-rmse:2.61203
# [20]	eval-rmse:2.50888	train-rmse:2.58683
# [21]	eval-rmse:2.48382	train-rmse:2.56189
# [22]	eval-rmse:2.45902	train-rmse:2.5372
# [23]	eval-rmse:2.43447	train-rmse:2.51276
# [24]	eval-rmse:2.41016	train-rmse:2.48857
# [25]	eval-rmse:2.38609	train-rmse:2.46462
# [26]	eval-rmse:2.36227	train-rmse:2.44091
# [27]	eval-rmse:2.33868	train-rmse:2.41745
# [28]	eval-rmse:2.31533	train-rmse:2.39422
# [29]	eval-rmse:2.29222	train-rmse:2.37122
# [30]	eval-rmse:2.26934	train-rmse:2.34847
# [31]	eval-rmse:2.24668	train-rmse:2.32593
# [32]	eval-rmse:2.22426	train-rmse:2.30363
# [33]	eval-rmse:2.20206	train-rmse:2.28156
# [34]	eval-rmse:2.18008	train-rmse:2.25971
# [35]	eval-rmse:2.15833	train-rmse:2.23808
# [36]	eval-rmse:2.13679	train-rmse:2.21667
# [37]	eval-rmse:2.11547	train-rmse:2.19548
# [38]	eval-rmse:2.09436	train-rmse:2.17451
# [39]	eval-rmse:2.07347	train-rmse:2.15375
# [40]	eval-rmse:2.05279	train-rmse:2.1332
# [41]	eval-rmse:2.03232	train-rmse:2.11286
# [42]	eval-rmse:2.01205	train-rmse:2.09272
# [43]	eval-rmse:1.99199	train-rmse:2.0728
# [44]	eval-rmse:1.97213	train-rmse:2.05307
# [45]	eval-rmse:1.95247	train-rmse:2.03355
# [46]	eval-rmse:1.93301	train-rmse:2.01423
# [47]	eval-rmse:1.91374	train-rmse:1.99511
# [48]	eval-rmse:1.89467	train-rmse:1.97618
# [49]	eval-rmse:1.8758	train-rmse:1.95744
# [50]	eval-rmse:1.85711	train-rmse:1.9389
# [51]	eval-rmse:1.83862	train-rmse:1.92055
# [52]	eval-rmse:1.82031	train-rmse:1.90239
# [53]	eval-rmse:1.80218	train-rmse:1.88441
# [54]	eval-rmse:1.78424	train-rmse:1.86662
# [55]	eval-rmse:1.76649	train-rmse:1.84901
# [56]	eval-rmse:1.74891	train-rmse:1.83159
# [57]	eval-rmse:1.73151	train-rmse:1.81434
# [58]	eval-rmse:1.71429	train-rmse:1.79727
# [59]	eval-rmse:1.69725	train-rmse:1.78038
# [60]	eval-rmse:1.68037	train-rmse:1.76366
# [61]	eval-rmse:1.66367	train-rmse:1.74712
# [62]	eval-rmse:1.64714	train-rmse:1.73074
# [63]	eval-rmse:1.63078	train-rmse:1.71454
# [64]	eval-rmse:1.61459	train-rmse:1.69851
# [65]	eval-rmse:1.59856	train-rmse:1.68264
# [66]	eval-rmse:1.58269	train-rmse:1.66693
# [67]	eval-rmse:1.56699	train-rmse:1.65139
# [68]	eval-rmse:1.55145	train-rmse:1.63602
# [69]	eval-rmse:1.53607	train-rmse:1.6208
# [70]	eval-rmse:1.52084	train-rmse:1.60574
# [71]	eval-rmse:1.50577	train-rmse:1.59084
# [72]	eval-rmse:1.49086	train-rmse:1.57609
# [73]	eval-rmse:1.4761	train-rmse:1.5615
# [74]	eval-rmse:1.46149	train-rmse:1.54706
# [75]	eval-rmse:1.44703	train-rmse:1.53278
# [76]	eval-rmse:1.43272	train-rmse:1.51864
# [77]	eval-rmse:1.41856	train-rmse:1.50465
# [78]	eval-rmse:1.40454	train-rmse:1.49081
# [79]	eval-rmse:1.39067	train-rmse:1.47712
# [80]	eval-rmse:1.37695	train-rmse:1.46357
# [81]	eval-rmse:1.36336	train-rmse:1.45016
# [82]	eval-rmse:1.34991	train-rmse:1.4369
# [83]	eval-rmse:1.33661	train-rmse:1.42377
# [84]	eval-rmse:1.32344	train-rmse:1.41079
# [85]	eval-rmse:1.31041	train-rmse:1.39794
# [86]	eval-rmse:1.29752	train-rmse:1.38523
# [87]	eval-rmse:1.28476	train-rmse:1.37265
# [88]	eval-rmse:1.27213	train-rmse:1.36021
# [89]	eval-rmse:1.25963	train-rmse:1.3479
# [90]	eval-rmse:1.24727	train-rmse:1.33573
# [91]	eval-rmse:1.23503	train-rmse:1.32368
# [92]	eval-rmse:1.22292	train-rmse:1.31177
# [93]	eval-rmse:1.21094	train-rmse:1.29998
# [94]	eval-rmse:1.19908	train-rmse:1.28832
# [95]	eval-rmse:1.18735	train-rmse:1.27678
# [96]	eval-rmse:1.17575	train-rmse:1.26537
# [97]	eval-rmse:1.16426	train-rmse:1.25408
# [98]	eval-rmse:1.1529	train-rmse:1.24291
# [99]	eval-rmse:1.14165	train-rmse:1.23187
# [100]	eval-rmse:1.13053	train-rmse:1.22094
# [101]	eval-rmse:1.11952	train-rmse:1.21013
# [102]	eval-rmse:1.10863	train-rmse:1.19945
# [103]	eval-rmse:1.09786	train-rmse:1.18887
# [104]	eval-rmse:1.08719	train-rmse:1.17842
# [105]	eval-rmse:1.07665	train-rmse:1.16807
# [106]	eval-rmse:1.06621	train-rmse:1.15785
# [107]	eval-rmse:1.05589	train-rmse:1.14773
# [108]	eval-rmse:1.04568	train-rmse:1.13772
# [109]	eval-rmse:1.03558	train-rmse:1.12783
# [110]	eval-rmse:1.02558	train-rmse:1.11804
# [111]	eval-rmse:1.01569	train-rmse:1.10837
# [112]	eval-rmse:1.00591	train-rmse:1.0988
# [113]	eval-rmse:0.996238	train-rmse:1.08933
# [114]	eval-rmse:0.986667	train-rmse:1.07998
# [115]	eval-rmse:0.9772	train-rmse:1.07072
# [116]	eval-rmse:0.967836	train-rmse:1.06157
# [117]	eval-rmse:0.958573	train-rmse:1.05252
# [399]	eval-rmse:0.336369	train-rmse:0.298068
# [400]	eval-rmse:0.336493	train-rmse:0.297877
# [401]	eval-rmse:0.336616	train-rmse:0.297689
# [402]	eval-rmse:0.336755	train-rmse:0.297504
# [403]	eval-rmse:0.337109	train-rmse:0.297277
# [404]	eval-rmse:0.337232	train-rmse:0.297097
# [405]	eval-rmse:0.337356	train-rmse:0.29692
# [406]	eval-rmse:0.33748	train-rmse:0.296746
# [407]	eval-rmse:0.337603	train-rmse:0.296575
# [408]	eval-rmse:0.337726	train-rmse:0.296406
# [409]	eval-rmse:0.337864	train-rmse:0.29624
# [410]	eval-rmse:0.33822	train-rmse:0.29603
# [411]	eval-rmse:0.338576	train-rmse:0.295824
# [412]	eval-rmse:0.338699	train-rmse:0.295665
# [413]	eval-rmse:0.338821	train-rmse:0.295508
# [414]	eval-rmse:0.338943	train-rmse:0.295353
# [415]	eval-rmse:0.339065	train-rmse:0.295201
# [416]	eval-rmse:0.339186	train-rmse:0.295052
# [417]	eval-rmse:0.339307	train-rmse:0.294905
# [418]	eval-rmse:0.339444	train-rmse:0.29476
# [419]	eval-rmse:0.339801	train-rmse:0.29457
# [420]	eval-rmse:0.339921	train-rmse:0.294429
# [421]	eval-rmse:0.340041	train-rmse:0.29429
# [422]	eval-rmse:0.34016	train-rmse:0.294154
# [423]	eval-rmse:0.340279	train-rmse:0.294019
# [424]	eval-rmse:0.340397	train-rmse:0.293887
# [425]	eval-rmse:0.340532	train-rmse:0.293757
# [426]	eval-rmse:0.340889	train-rmse:0.29358
# [427]	eval-rmse:0.341245	train-rmse:0.293406
# [428]	eval-rmse:0.341362	train-rmse:0.293281
# [429]	eval-rmse:0.341478	train-rmse:0.293158
# [430]	eval-rmse:0.341594	train-rmse:0.293036
# [431]	eval-rmse:0.341709	train-rmse:0.292917
# [432]	eval-rmse:0.341824	train-rmse:0.292799
# [433]	eval-rmse:0.341956	train-rmse:0.292683
# [434]	eval-rmse:0.342311	train-rmse:0.292521
# [435]	eval-rmse:0.342665	train-rmse:0.29236
# [436]	eval-rmse:0.342778	train-rmse:0.292249
# [437]	eval-rmse:0.342891	train-rmse:0.292139
# [438]	eval-rmse:0.343003	train-rmse:0.292031
# [439]	eval-rmse:0.343114	train-rmse:0.291925
# [440]	eval-rmse:0.343248	train-rmse:0.29182
# [441]	eval-rmse:0.343359	train-rmse:0.291717
# [442]	eval-rmse:0.343492	train-rmse:0.291615
# [443]	eval-rmse:0.343844	train-rmse:0.291466
# [444]	eval-rmse:0.343977	train-rmse:0.291367
# [445]	eval-rmse:0.344327	train-rmse:0.291221
# [446]	eval-rmse:0.344459	train-rmse:0.291124
# [447]	eval-rmse:0.344809	train-rmse:0.290981
# [448]	eval-rmse:0.34494	train-rmse:0.290887
# [449]	eval-rmse:0.345288	train-rmse:0.290747
# [450]	eval-rmse:0.345418	train-rmse:0.290655
# [451]	eval-rmse:0.345764	train-rmse:0.290518
# [452]	eval-rmse:0.345894	train-rmse:0.290429
# [453]	eval-rmse:0.346239	train-rmse:0.290295
# [454]	eval-rmse:0.346367	train-rmse:0.290208
# [455]	eval-rmse:0.346711	train-rmse:0.290076
# [456]	eval-rmse:0.346838	train-rmse:0.289991
# [457]	eval-rmse:0.347181	train-rmse:0.289863
# [458]	eval-rmse:0.347307	train-rmse:0.28978
# [459]	eval-rmse:0.347648	train-rmse:0.289654
# [460]	eval-rmse:0.347773	train-rmse:0.289573
# [461]	eval-rmse:0.348113	train-rmse:0.289449
# [462]	eval-rmse:0.348237	train-rmse:0.28937
# [463]	eval-rmse:0.348575	train-rmse:0.289249
# [464]	eval-rmse:0.348698	train-rmse:0.289172
# [465]	eval-rmse:0.349034	train-rmse:0.289054
# [466]	eval-rmse:0.349093	train-rmse:0.288979
# [467]	eval-rmse:0.349428	train-rmse:0.288862
# [468]	eval-rmse:0.349549	train-rmse:0.288789
# [469]	eval-rmse:0.349882	train-rmse:0.288675
# [470]	eval-rmse:0.350002	train-rmse:0.288603
# [471]	eval-rmse:0.350333	train-rmse:0.288492
# [472]	eval-rmse:0.350452	train-rmse:0.288422
# [473]	eval-rmse:0.350782	train-rmse:0.288312
# [474]	eval-rmse:0.350836	train-rmse:0.288244
# [475]	eval-rmse:0.351164	train-rmse:0.288136
# [476]	eval-rmse:0.35128	train-rmse:0.288069
# [477]	eval-rmse:0.351607	train-rmse:0.287964
# [478]	eval-rmse:0.351622	train-rmse:0.287898
# [479]	eval-rmse:0.351946	train-rmse:0.287795
# [480]	eval-rmse:0.35227	train-rmse:0.287693
# [481]	eval-rmse:0.352384	train-rmse:0.28763
# [482]	eval-rmse:0.352705	train-rmse:0.28753
# [483]	eval-rmse:0.352716	train-rmse:0.287468
# [484]	eval-rmse:0.353036	train-rmse:0.287369
# [485]	eval-rmse:0.353206	train-rmse:0.287273
# [486]	eval-rmse:0.353524	train-rmse:0.287177
# [487]	eval-rmse:0.353635	train-rmse:0.287117
# [488]	eval-rmse:0.353951	train-rmse:0.287022
# [489]	eval-rmse:0.354117	train-rmse:0.286929
# [490]	eval-rmse:0.354432	train-rmse:0.286837
# [491]	eval-rmse:0.35454	train-rmse:0.286779
# [492]	eval-rmse:0.354852	train-rmse:0.286688
# [493]	eval-rmse:0.355015	train-rmse:0.286598
# [494]	eval-rmse:0.355326	train-rmse:0.286508
# [495]	eval-rmse:0.355328	train-rmse:0.286453
# [496]	eval-rmse:0.355637	train-rmse:0.286365
# [497]	eval-rmse:0.355944	train-rmse:0.286278
# [498]	eval-rmse:0.356007	train-rmse:0.286164
# [499]	eval-rmse:0.356313	train-rmse:0.286079

# %%
plt.figure(figsize=(10, 5))
train_metric = evals_result['train']['rmse']
plt.plot(train_metric, label='train rmse')
eval_metric = evals_result['eval']['rmse']
plt.plot(eval_metric, label='eval rmse')
plt.grid()
plt.legend()
plt.xlabel('rounds')
plt.ylabel('rmse')
plt.ylim(0, 5)
plt.show()

# %%
from sklearn.metrics import mean_squared_error
pred = bst.predict(dvalid)

rmse = np.sqrt(mean_squared_error(Y_train, pred))
print(np.exp(rmse))
# Out:
# 1.6102454171875114

# %%
dtest = xgb.DMatrix(np.log(test))
pred = pd.DataFrame()
pred["Id"] = test_index
ans = (np.exp(bst.predict(dtest))*2.0).round(0)/2
pred["DBH"] = ans
pred.to_csv("DBH_Log.csv", index=False)
