# %%
from jupyterthemes import jtplot
jtplot.style(theme='monokai') 
import gdal
import numpy as np
import re
import os, io, re

# import image
train_path = './train_crowns/train_crowns/'
test_path = "./test_crowns/"
# filename を全て入れる
train_files = []
test_files = []
for filename in os.listdir(train_path):
    if os.path.isfile(os.path.join(train_path, filename)):
        train_files.append(filename)
for filename in os.listdir(test_path):
    if os.path.isfile(os.path.join(test_path, filename)):
        test_files.append(filename)

# .tifのファイルを選んで入れる
train_img = []
test_img= []
for name in train_files:
    if re.search(r"(.tif)$", name):
        train_img.append(name)
for name in test_files:
    if re.search(r"(.tif)$", name):
        test_img.append(name)
# print(img_files)

# %%
train_height = []
train_DBH = []
train_index = []
test_height = []
test_index = []

for imgfile in train_files:
    image = gdal.Open("C:/Users/owner/Kaggle/GE_Kaggle01/train_crowns/train_crowns/"+imgfile, gdal.GA_ReadOnly)
    a = np.array([image.GetRasterBand(i + 1).ReadAsArray() for i in range(image.RasterCount)])
    train_height.append(a[0<a].mean())
#     print(a[a>0].mean())
    file = os.path.splitext(imgfile)[0]
    file_split = [i for i in file.split("_")]
    train_index.append(file_split[0])
    train_DBH.append(float(file_split[3]))
#     print(float(file_split[3]))
    
for imgfile in test_files:
    image = gdal.Open("C:/Users/owner/Kaggle/GE_Kaggle01/test_crowns/"+imgfile, gdal.GA_ReadOnly)
    a = np.array([image.GetRasterBand(i + 1).ReadAsArray() for i in range(image.RasterCount)])
    test_height.append(a[a>0].mean())
#     print(a[a>0].mean())
    file = os.path.basename(imgfile)
    file_split = [i for i in file.split("_")]
    test_index.append(file_split[0])
#     print(file_split[0])

# %%
import pandas as pd
index = pd.Index(train_index)
d = {"Height": train_height}
train = pd.DataFrame(data=d, index=index)
# print(train)
target = pd.DataFrame({"DBH": train_DBH}, index=index)
# print(target)
test = pd.DataFrame(data={"Height": test_height}, index=pd.Index(test_index))

# %%
tmp = pd.DataFrame({"Height": train_height, "DBH": train_DBH}, index=index)
# print(tmp)
import matplotlib.pyplot as plt
x = tmp["DBH"]
y = tmp["Height"]
plt.scatter(x,y)
plt.xlabel("DBH [cm]")
plt.ylabel("Height [m]")
plt.axis([0,70,0,70])
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, Y_train, X_target, Y_target = train_test_split(train, target, random_state=0)
# print(X_train.shape, Y_train.shape, X_valid.shape, Y_valid.shape)

# %%
import xgboost as xgb
dtrain = xgb.DMatrix(X_train, label=X_target)
dvalid = xgb.DMatrix(Y_train, label=Y_target)
num_round = 500
evallist = [(dvalid, "eval"), (dtrain, "train")]
evals_result = {}
param = {
    "max_depth": 3,
    "eta": 0.01,
    "objective": "reg:squarederror",
}
bst = xgb.train(
                        param, dtrain,
                        num_round,
                        evallist,
                        evals_result=evals_result,
                        # 一定ラウンド回しても改善が見込めない場合は学習を打ち切る
                        early_stopping_rounds=1000
)
# Out:
# [0]	eval-rmse:38.3386	train-rmse:42.6181
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
# Will train until train-rmse hasn't improved in 1000 rounds.
# [1]	eval-rmse:37.9601	train-rmse:42.242
# [2]	eval-rmse:37.5858	train-rmse:41.87
# [3]	eval-rmse:37.2154	train-rmse:41.5019
# [4]	eval-rmse:36.8491	train-rmse:41.1378
# [5]	eval-rmse:36.4867	train-rmse:40.7776
# [6]	eval-rmse:36.1283	train-rmse:40.4214
# [7]	eval-rmse:35.7737	train-rmse:40.0689
# [8]	eval-rmse:35.4231	train-rmse:39.7203
# [9]	eval-rmse:35.0762	train-rmse:39.3755
# [10]	eval-rmse:34.7332	train-rmse:39.0344
# [11]	eval-rmse:34.3939	train-rmse:38.6971
# [12]	eval-rmse:34.0584	train-rmse:38.3634
# [13]	eval-rmse:33.7266	train-rmse:38.0333
# [14]	eval-rmse:33.3984	train-rmse:37.7069
# [15]	eval-rmse:33.0739	train-rmse:37.3841
# [16]	eval-rmse:32.7529	train-rmse:37.0648
# [17]	eval-rmse:32.4356	train-rmse:36.749
# [18]	eval-rmse:32.1218	train-rmse:36.4367
# [19]	eval-rmse:31.8115	train-rmse:36.1279
# [20]	eval-rmse:31.5046	train-rmse:35.8225
# [21]	eval-rmse:31.2013	train-rmse:35.5204
# [22]	eval-rmse:30.9013	train-rmse:35.2218
# [23]	eval-rmse:30.6048	train-rmse:34.9264
# [24]	eval-rmse:30.3116	train-rmse:34.6344
# [25]	eval-rmse:30.0218	train-rmse:34.3456
# [26]	eval-rmse:29.7352	train-rmse:34.0601
# [27]	eval-rmse:29.452	train-rmse:33.7777
# [28]	eval-rmse:29.172	train-rmse:33.4986
# [29]	eval-rmse:28.8952	train-rmse:33.2226
# [30]	eval-rmse:28.6216	train-rmse:32.9497
# [31]	eval-rmse:28.3512	train-rmse:32.6799
# [32]	eval-rmse:28.0839	train-rmse:32.4132
# [33]	eval-rmse:27.8198	train-rmse:32.1495
# [34]	eval-rmse:27.5471	train-rmse:31.8859
# [35]	eval-rmse:27.2891	train-rmse:31.6281
# [36]	eval-rmse:27.0226	train-rmse:31.3702
# [37]	eval-rmse:26.7706	train-rmse:31.1182
# [38]	eval-rmse:26.5103	train-rmse:30.866
# [39]	eval-rmse:26.2642	train-rmse:30.6196
# [40]	eval-rmse:26.0099	train-rmse:30.373
# [41]	eval-rmse:25.7696	train-rmse:30.1322
# [42]	eval-rmse:25.5212	train-rmse:29.8911
# [43]	eval-rmse:25.2867	train-rmse:29.6557
# [44]	eval-rmse:25.0442	train-rmse:29.42
# [45]	eval-rmse:24.8153	train-rmse:29.19
# [46]	eval-rmse:24.5785	train-rmse:28.9595
# [47]	eval-rmse:24.3552	train-rmse:28.7348
# [48]	eval-rmse:24.124	train-rmse:28.5095
# [49]	eval-rmse:23.9062	train-rmse:28.2899
# [50]	eval-rmse:23.6819	train-rmse:28.0695
# [51]	eval-rmse:23.4695	train-rmse:27.8549
# [52]	eval-rmse:23.2508	train-rmse:27.6395
# [53]	eval-rmse:23.0348	train-rmse:27.4265
# [54]	eval-rmse:22.8201	train-rmse:27.2161
# [55]	eval-rmse:22.6182	train-rmse:27.0113
# [56]	eval-rmse:22.4103	train-rmse:26.8055
# [57]	eval-rmse:22.2144	train-rmse:26.6047
# [58]	eval-rmse:22.0117	train-rmse:26.4035
# [59]	eval-rmse:21.8229	train-rmse:26.2081
# [60]	eval-rmse:21.6347	train-rmse:26.0142
# [61]	eval-rmse:21.4398	train-rmse:25.8197
# [62]	eval-rmse:21.2474	train-rmse:25.6276
# [63]	eval-rmse:21.0668	train-rmse:25.4404
# [64]	eval-rmse:20.8795	train-rmse:25.2526
# [65]	eval-rmse:20.7053	train-rmse:25.0706
# [66]	eval-rmse:20.532	train-rmse:24.8899
# [67]	eval-rmse:20.3521	train-rmse:24.7086
# [68]	eval-rmse:20.1747	train-rmse:24.5294
# [69]	eval-rmse:20.0087	train-rmse:24.355
# [70]	eval-rmse:19.8361	train-rmse:24.18
# [71]	eval-rmse:19.6758	train-rmse:24.0107
# [72]	eval-rmse:19.5168	train-rmse:23.8425
# [73]	eval-rmse:19.3513	train-rmse:23.6736
# [74]	eval-rmse:19.1881	train-rmse:23.5067
# [75]	eval-rmse:19.0361	train-rmse:23.3445
# [76]	eval-rmse:18.8776	train-rmse:23.1815
# [77]	eval-rmse:18.7301	train-rmse:23.0232
# [78]	eval-rmse:18.5853	train-rmse:22.8678
# [79]	eval-rmse:18.4335	train-rmse:22.7106
# [80]	eval-rmse:18.284	train-rmse:22.5553
# [81]	eval-rmse:18.1453	train-rmse:22.4046
# [82]	eval-rmse:18.0002	train-rmse:22.253
# [83]	eval-rmse:17.8659	train-rmse:22.106
# [84]	eval-rmse:17.7337	train-rmse:21.9619
# [85]	eval-rmse:17.5951	train-rmse:21.8157
# [86]	eval-rmse:17.4586	train-rmse:21.6714
# [87]	eval-rmse:17.3285	train-rmse:21.522
# [88]	eval-rmse:17.1963	train-rmse:21.3811
# [89]	eval-rmse:17.0706	train-rmse:21.235
# [90]	eval-rmse:16.9439	train-rmse:21.098
# [91]	eval-rmse:16.8257	train-rmse:20.9659
# [92]	eval-rmse:16.7017	train-rmse:20.8318
# [93]	eval-rmse:16.5842	train-rmse:20.6922
# [94]	eval-rmse:16.4643	train-rmse:20.5612
# [95]	eval-rmse:16.352	train-rmse:20.4248
# [96]	eval-rmse:16.2361	train-rmse:20.297
# [97]	eval-rmse:16.1222	train-rmse:20.1708
# [98]	eval-rmse:16.016	train-rmse:20.039
# [99]	eval-rmse:15.906	train-rmse:19.9159
# [100]	eval-rmse:15.8048	train-rmse:19.7982
# [101]	eval-rmse:15.7042	train-rmse:19.6708
# [102]	eval-rmse:15.5999	train-rmse:19.5523
# [103]	eval-rmse:15.4974	train-rmse:19.4353
# [104]	eval-rmse:15.4076	train-rmse:19.3233
# [105]	eval-rmse:15.3145	train-rmse:19.2017
# [106]	eval-rmse:15.2175	train-rmse:19.089
# [107]	eval-rmse:15.1208	train-rmse:18.9759
# [108]	eval-rmse:15.0371	train-rmse:18.8637
# [109]	eval-rmse:14.944	train-rmse:18.7534
# [110]	eval-rmse:14.8585	train-rmse:18.6385
# [111]	eval-rmse:14.7699	train-rmse:18.531
# [112]	eval-rmse:14.6917	train-rmse:18.424
# [113]	eval-rmse:14.606	train-rmse:18.3188
# [114]	eval-rmse:14.522	train-rmse:18.215
# [115]	eval-rmse:14.4503	train-rmse:18.1178
# [116]	eval-rmse:14.3751	train-rmse:18.0104
# [117]	eval-rmse:14.2961	train-rmse:17.9103
# [118]	eval-rmse:14.2278	train-rmse:17.8107
# [119]	eval-rmse:14.152	train-rmse:17.7131
# [120]	eval-rmse:14.0834	train-rmse:17.6106
# [121]	eval-rmse:14.0117	train-rmse:17.5077
# [122]	eval-rmse:13.9408	train-rmse:17.4135
# [123]	eval-rmse:13.881	train-rmse:17.326
# [124]	eval-rmse:13.822	train-rmse:17.2334
# [125]	eval-rmse:13.7566	train-rmse:17.1352
# [126]	eval-rmse:13.6928	train-rmse:17.0382
# [127]	eval-rmse:13.631	train-rmse:16.9424
# [128]	eval-rmse:13.5783	train-rmse:16.8605
# [129]	eval-rmse:13.5191	train-rmse:16.7669
# [130]	eval-rmse:13.4615	train-rmse:16.6745
# [131]	eval-rmse:13.4128	train-rmse:16.5959
# [132]	eval-rmse:13.3581	train-rmse:16.5057
# [133]	eval-rmse:13.305	train-rmse:16.4166
# [134]	eval-rmse:13.2524	train-rmse:16.3353
# [135]	eval-rmse:13.2087	train-rmse:16.2608
# [136]	eval-rmse:13.1597	train-rmse:16.1749
# [137]	eval-rmse:13.1123	train-rmse:16.09
# [138]	eval-rmse:13.0662	train-rmse:16.0062
# [139]	eval-rmse:13.0288	train-rmse:15.9324
# [140]	eval-rmse:12.9853	train-rmse:15.8506
# [141]	eval-rmse:12.9463	train-rmse:15.7791
# [142]	eval-rmse:12.9055	train-rmse:15.6992
# [143]	eval-rmse:12.8732	train-rmse:15.6291
# [144]	eval-rmse:12.8349	train-rmse:15.5511
# [145]	eval-rmse:12.7979	train-rmse:15.4741
# [146]	eval-rmse:12.7693	train-rmse:15.4066
# [147]	eval-rmse:12.7348	train-rmse:15.3314
# [148]	eval-rmse:12.7016	train-rmse:15.257
# [149]	eval-rmse:12.6695	train-rmse:15.1838
# [150]	eval-rmse:12.6455	train-rmse:15.1195
# [151]	eval-rmse:12.6158	train-rmse:15.0478
# [152]	eval-rmse:12.5871	train-rmse:14.9773
# [153]	eval-rmse:12.5668	train-rmse:14.9154
# [154]	eval-rmse:12.5403	train-rmse:14.8465
# [155]	eval-rmse:12.5149	train-rmse:14.7783
# [156]	eval-rmse:12.4905	train-rmse:14.7112
# [157]	eval-rmse:12.4744	train-rmse:14.6523
# [158]	eval-rmse:12.452	train-rmse:14.5866
# [159]	eval-rmse:12.4307	train-rmse:14.522
# [160]	eval-rmse:12.4174	train-rmse:14.4652
# [161]	eval-rmse:12.3979	train-rmse:14.4021
# [162]	eval-rmse:12.3794	train-rmse:14.3398
# [163]	eval-rmse:12.3619	train-rmse:14.2784
# [164]	eval-rmse:12.3521	train-rmse:14.2243
# [165]	eval-rmse:12.3363	train-rmse:14.1644
# [166]	eval-rmse:12.3221	train-rmse:14.1083
# [167]	eval-rmse:12.308	train-rmse:14.05
# [168]	eval-rmse:12.3016	train-rmse:13.9985
# [169]	eval-rmse:12.2923	train-rmse:13.9476
# [170]	eval-rmse:12.2806	train-rmse:13.8913
# [171]	eval-rmse:12.2701	train-rmse:13.8387
# [172]	eval-rmse:12.2599	train-rmse:13.7839
# [173]	eval-rmse:12.25	train-rmse:13.7349
# [174]	eval-rmse:12.2413	train-rmse:13.6815
# [175]	eval-rmse:12.237	train-rmse:13.6347
# [176]	eval-rmse:12.2301	train-rmse:13.5853
# [177]	eval-rmse:12.2233	train-rmse:13.5388
# [178]	eval-rmse:12.2173	train-rmse:13.4878
# [179]	eval-rmse:12.2122	train-rmse:13.4403
# [180]	eval-rmse:12.2075	train-rmse:13.3907
# [181]	eval-rmse:12.2032	train-rmse:13.3409
# [182]	eval-rmse:12.1998	train-rmse:13.2972
# [183]	eval-rmse:12.1967	train-rmse:13.2487
# [184]	eval-rmse:12.1942	train-rmse:13.2009
# [185]	eval-rmse:12.1924	train-rmse:13.1538
# [186]	eval-rmse:12.191	train-rmse:13.1074
# [187]	eval-rmse:12.1908	train-rmse:13.0663
# [188]	eval-rmse:12.1906	train-rmse:13.0211
# [189]	eval-rmse:12.191	train-rmse:12.979
# [190]	eval-rmse:12.1917	train-rmse:12.935
# [191]	eval-rmse:12.1936	train-rmse:12.8959
# [192]	eval-rmse:12.1954	train-rmse:12.853
# [193]	eval-rmse:12.1975	train-rmse:12.8131
# [194]	eval-rmse:12.2	train-rmse:12.7714
# [195]	eval-rmse:12.203	train-rmse:12.7304
# [196]	eval-rmse:12.2074	train-rmse:12.6936
# [197]	eval-rmse:12.2113	train-rmse:12.6559
# [198]	eval-rmse:12.2154	train-rmse:12.6164
# [199]	eval-rmse:12.22	train-rmse:12.5774
# [200]	eval-rmse:12.2262	train-rmse:12.5424
# [201]	eval-rmse:12.2314	train-rmse:12.5067
# [202]	eval-rmse:12.237	train-rmse:12.4693
# [203]	eval-rmse:12.243	train-rmse:12.4325
# [204]	eval-rmse:12.2492	train-rmse:12.3983
# [205]	eval-rmse:12.2574	train-rmse:12.3654
# [206]	eval-rmse:12.2643	train-rmse:12.3299
# [207]	eval-rmse:12.2713	train-rmse:12.2972
# [208]	eval-rmse:12.2788	train-rmse:12.2628
# [209]	eval-rmse:12.2884	train-rmse:12.2313
# [210]	eval-rmse:12.2964	train-rmse:12.1978
# [211]	eval-rmse:12.3046	train-rmse:12.1668
# [212]	eval-rmse:12.3131	train-rmse:12.1343
# [213]	eval-rmse:12.324	train-rmse:12.1043
# [214]	eval-rmse:12.3331	train-rmse:12.0726
# [215]	eval-rmse:12.3465	train-rmse:12.0401
# [216]	eval-rmse:12.3591	train-rmse:12.008
# [217]	eval-rmse:12.3719	train-rmse:11.9764
# [218]	eval-rmse:12.3862	train-rmse:11.9452
# [219]	eval-rmse:12.3997	train-rmse:11.9145
# [220]	eval-rmse:12.4134	train-rmse:11.8842
# [221]	eval-rmse:12.4275	train-rmse:11.8544
# [222]	eval-rmse:12.4429	train-rmse:11.8249
# [223]	eval-rmse:12.4574	train-rmse:11.7959
# [224]	eval-rmse:12.4722	train-rmse:11.7673
# [225]	eval-rmse:12.4884	train-rmse:11.7391
# [226]	eval-rmse:12.5036	train-rmse:11.7113
# [227]	eval-rmse:12.5183	train-rmse:11.6884
# [228]	eval-rmse:12.5332	train-rmse:11.666
# [229]	eval-rmse:12.5483	train-rmse:11.6438
# [230]	eval-rmse:12.5635	train-rmse:11.622
# [231]	eval-rmse:12.5789	train-rmse:11.6005
# [232]	eval-rmse:12.5944	train-rmse:11.5794
# [233]	eval-rmse:12.6101	train-rmse:11.5586
# [234]	eval-rmse:12.6259	train-rmse:11.5381
# [235]	eval-rmse:12.6419	train-rmse:11.5179
# [236]	eval-rmse:12.658	train-rmse:11.498
# [237]	eval-rmse:12.6742	train-rmse:11.4784
# [238]	eval-rmse:12.6906	train-rmse:11.4592
# [239]	eval-rmse:12.707	train-rmse:11.4402
# [240]	eval-rmse:12.7236	train-rmse:11.4215
# [241]	eval-rmse:12.7402	train-rmse:11.4031
# [242]	eval-rmse:12.7569	train-rmse:11.385
# [243]	eval-rmse:12.7738	train-rmse:11.3672
# [244]	eval-rmse:12.7907	train-rmse:11.3497
# [245]	eval-rmse:12.8077	train-rmse:11.3324
# [246]	eval-rmse:12.8247	train-rmse:11.3154
# [247]	eval-rmse:12.8418	train-rmse:11.2986
# [248]	eval-rmse:12.859	train-rmse:11.2822
# [249]	eval-rmse:12.8763	train-rmse:11.2659
# [250]	eval-rmse:12.8936	train-rmse:11.25
# [251]	eval-rmse:12.9109	train-rmse:11.2342
# [252]	eval-rmse:12.9283	train-rmse:11.2187
# [253]	eval-rmse:12.9458	train-rmse:11.2035
# [254]	eval-rmse:12.9632	train-rmse:11.1885
# [255]	eval-rmse:12.9808	train-rmse:11.1737
# [256]	eval-rmse:12.9983	train-rmse:11.1592
# [257]	eval-rmse:13.0159	train-rmse:11.1449
# [258]	eval-rmse:13.0334	train-rmse:11.1308
# [259]	eval-rmse:13.051	train-rmse:11.1169
# [260]	eval-rmse:13.0687	train-rmse:11.1033
# [261]	eval-rmse:13.0863	train-rmse:11.0898
# [262]	eval-rmse:13.1039	train-rmse:11.0766
# [263]	eval-rmse:13.1216	train-rmse:11.0636
# [264]	eval-rmse:13.1392	train-rmse:11.0507
# [265]	eval-rmse:13.1468	train-rmse:11.0386
# [266]	eval-rmse:13.1543	train-rmse:11.0266
# [267]	eval-rmse:13.1618	train-rmse:11.0148
# [268]	eval-rmse:13.1694	train-rmse:11.0032
# [269]	eval-rmse:13.1769	train-rmse:10.9918
# [270]	eval-rmse:13.1844	train-rmse:10.9805
# [271]	eval-rmse:13.1919	train-rmse:10.9695
# [272]	eval-rmse:13.1994	train-rmse:10.9586
# [273]	eval-rmse:13.2069	train-rmse:10.9479
# [274]	eval-rmse:13.2144	train-rmse:10.9373
# [275]	eval-rmse:13.2218	train-rmse:10.927
# [276]	eval-rmse:13.2293	train-rmse:10.9167
# [277]	eval-rmse:13.2367	train-rmse:10.9067
# [278]	eval-rmse:13.2441	train-rmse:10.8968
# [279]	eval-rmse:13.2515	train-rmse:10.8871
# [280]	eval-rmse:13.2589	train-rmse:10.8775
# [281]	eval-rmse:13.2662	train-rmse:10.868
# [282]	eval-rmse:13.2736	train-rmse:10.8587
# [283]	eval-rmse:13.2809	train-rmse:10.8496
# [284]	eval-rmse:13.2881	train-rmse:10.8406
# [285]	eval-rmse:13.2954	train-rmse:10.8317
# [286]	eval-rmse:13.3026	train-rmse:10.823
# [287]	eval-rmse:13.3098	train-rmse:10.8144
# [288]	eval-rmse:13.317	train-rmse:10.806
# [289]	eval-rmse:13.3242	train-rmse:10.7977
# [290]	eval-rmse:13.3313	train-rmse:10.7895
# [291]	eval-rmse:13.3384	train-rmse:10.7814
# [292]	eval-rmse:13.3455	train-rmse:10.7735
# [293]	eval-rmse:13.3525	train-rmse:10.7657
# [294]	eval-rmse:13.3595	train-rmse:10.758
# [295]	eval-rmse:13.3665	train-rmse:10.7505
# [296]	eval-rmse:13.3734	train-rmse:10.743
# [297]	eval-rmse:13.3804	train-rmse:10.7357
# [298]	eval-rmse:13.3872	train-rmse:10.7285
# [299]	eval-rmse:13.3941	train-rmse:10.7214
# [300]	eval-rmse:13.4009	train-rmse:10.7144
# [301]	eval-rmse:13.4077	train-rmse:10.7075
# [302]	eval-rmse:13.4145	train-rmse:10.7007
# [303]	eval-rmse:13.4212	train-rmse:10.694
# [304]	eval-rmse:13.4279	train-rmse:10.6875
# [305]	eval-rmse:13.4345	train-rmse:10.681
# [306]	eval-rmse:13.4411	train-rmse:10.6746
# [307]	eval-rmse:13.4477	train-rmse:10.6684
# [308]	eval-rmse:13.4542	train-rmse:10.6622
# [309]	eval-rmse:13.4607	train-rmse:10.6561
# [310]	eval-rmse:13.4672	train-rmse:10.6501
# [311]	eval-rmse:13.4737	train-rmse:10.6442
# [312]	eval-rmse:13.48	train-rmse:10.6384
# [313]	eval-rmse:13.4864	train-rmse:10.6327
# [314]	eval-rmse:13.4927	train-rmse:10.6271
# [315]	eval-rmse:13.499	train-rmse:10.6216
# [316]	eval-rmse:13.5053	train-rmse:10.6161
# [317]	eval-rmse:13.5115	train-rmse:10.6108
# [318]	eval-rmse:13.5177	train-rmse:10.6055
# [319]	eval-rmse:13.5238	train-rmse:10.6003
# [320]	eval-rmse:13.5257	train-rmse:10.5952
# [321]	eval-rmse:13.5432	train-rmse:10.5883
# [322]	eval-rmse:13.5492	train-rmse:10.5833
# [323]	eval-rmse:13.5552	train-rmse:10.5784
# [324]	eval-rmse:13.557	train-rmse:10.5736
# [325]	eval-rmse:13.5744	train-rmse:10.567
# [326]	eval-rmse:13.5917	train-rmse:10.5605
# [327]	eval-rmse:13.5933	train-rmse:10.5559
# [328]	eval-rmse:13.6106	train-rmse:10.5495
# [329]	eval-rmse:13.6164	train-rmse:10.545
# [330]	eval-rmse:13.6179	train-rmse:10.5405
# [331]	eval-rmse:13.6351	train-rmse:10.5344
# [332]	eval-rmse:13.6407	train-rmse:10.53
# [333]	eval-rmse:13.6422	train-rmse:10.5257
# [334]	eval-rmse:13.6592	train-rmse:10.5198
# [335]	eval-rmse:13.6762	train-rmse:10.5139
# [336]	eval-rmse:13.6776	train-rmse:10.5098
# [337]	eval-rmse:13.6945	train-rmse:10.504
# [338]	eval-rmse:13.6999	train-rmse:10.5
# [339]	eval-rmse:13.7011	train-rmse:10.496
# [340]	eval-rmse:13.7179	train-rmse:10.4904
# [341]	eval-rmse:13.7233	train-rmse:10.4866
# [342]	eval-rmse:13.7244	train-rmse:10.4828
# [343]	eval-rmse:13.7411	train-rmse:10.4773
# [344]	eval-rmse:13.7577	train-rmse:10.472
# [345]	eval-rmse:13.7587	train-rmse:10.4683
# [346]	eval-rmse:13.7752	train-rmse:10.4631
# [347]	eval-rmse:13.7762	train-rmse:10.4595
# [348]	eval-rmse:13.7926	train-rmse:10.4543
# [349]	eval-rmse:13.7977	train-rmse:10.4509
# [350]	eval-rmse:13.7985	train-rmse:10.4474
# [351]	eval-rmse:13.8149	train-rmse:10.4424
# [352]	eval-rmse:13.8311	train-rmse:10.4375
# [353]	eval-rmse:13.8318	train-rmse:10.4342
# [354]	eval-rmse:13.848	train-rmse:10.4293
# [355]	eval-rmse:13.8487	train-rmse:10.4261
# [356]	eval-rmse:13.8648	train-rmse:10.4213
# [357]	eval-rmse:13.8745	train-rmse:10.4173
# [358]	eval-rmse:13.8905	train-rmse:10.4126
# [359]	eval-rmse:13.891	train-rmse:10.4095
# [360]	eval-rmse:13.9069	train-rmse:10.405
# [361]	eval-rmse:13.9227	train-rmse:10.4005
# [362]	eval-rmse:13.9275	train-rmse:10.394
# [363]	eval-rmse:13.9432	train-rmse:10.3896
# [364]	eval-rmse:13.9526	train-rmse:10.3857
# [365]	eval-rmse:13.9682	train-rmse:10.3814
# [366]	eval-rmse:13.9729	train-rmse:10.3751
# [367]	eval-rmse:13.9884	train-rmse:10.3709
# [368]	eval-rmse:13.9886	train-rmse:10.368
# [369]	eval-rmse:14.004	train-rmse:10.3639
# [370]	eval-rmse:14.0131	train-rmse:10.3602
# [371]	eval-rmse:14.0285	train-rmse:10.3561
# [372]	eval-rmse:14.0329	train-rmse:10.35
# [373]	eval-rmse:14.0481	train-rmse:10.346
# [374]	eval-rmse:14.0481	train-rmse:10.3434
# [375]	eval-rmse:14.0632	train-rmse:10.3394
# [376]	eval-rmse:14.0783	train-rmse:10.3356
# [377]	eval-rmse:14.0826	train-rmse:10.3296
# [378]	eval-rmse:14.0975	train-rmse:10.3258
# [379]	eval-rmse:14.1063	train-rmse:10.3224
# [380]	eval-rmse:14.1212	train-rmse:10.3187
# [381]	eval-rmse:14.1208	train-rmse:10.3162
# [382]	eval-rmse:14.1356	train-rmse:10.3125
# [383]	eval-rmse:14.1397	train-rmse:10.3068
# [384]	eval-rmse:14.1395	train-rmse:10.2999
# [385]	eval-rmse:14.1391	train-rmse:10.2975
# [386]	eval-rmse:14.1537	train-rmse:10.294
# [387]	eval-rmse:14.1535	train-rmse:10.2873
# [388]	eval-rmse:14.1578	train-rmse:10.2822
# [389]	eval-rmse:14.1723	train-rmse:10.2787
# [390]	eval-rmse:14.1806	train-rmse:10.2755
# [391]	eval-rmse:14.1951	train-rmse:10.2721
# [392]	eval-rmse:14.1989	train-rmse:10.2666
# [393]	eval-rmse:14.1986	train-rmse:10.2601
# [394]	eval-rmse:14.202	train-rmse:10.2554
# [395]	eval-rmse:14.2163	train-rmse:10.252
# [396]	eval-rmse:14.2157	train-rmse:10.2499
# [397]	eval-rmse:14.2153	train-rmse:10.2435
# [398]	eval-rmse:14.2191	train-rmse:10.2382
# [399]	eval-rmse:14.2332	train-rmse:10.2349
# [400]	eval-rmse:14.2329	train-rmse:10.2287
# [401]	eval-rmse:14.2361	train-rmse:10.2241
# [402]	eval-rmse:14.243	train-rmse:10.2211
# [403]	eval-rmse:14.257	train-rmse:10.2179
# [404]	eval-rmse:14.2611	train-rmse:10.2159
# [405]	eval-rmse:14.2607	train-rmse:10.2098
# [406]	eval-rmse:14.2638	train-rmse:10.2053
# [407]	eval-rmse:14.2776	train-rmse:10.2022
# [408]	eval-rmse:14.2813	train-rmse:10.1975
# [409]	eval-rmse:14.2808	train-rmse:10.1915
# [410]	eval-rmse:14.2946	train-rmse:10.1885
# [411]	eval-rmse:14.2976	train-rmse:10.184
# [412]	eval-rmse:14.2971	train-rmse:10.1781
# [413]	eval-rmse:14.301	train-rmse:10.1762
# [414]	eval-rmse:14.3145	train-rmse:10.1733
# [415]	eval-rmse:14.3178	train-rmse:10.1683
# [416]	eval-rmse:14.3313	train-rmse:10.1654
# [417]	eval-rmse:14.3341	train-rmse:10.161
# [418]	eval-rmse:14.3335	train-rmse:10.1553
# [419]	eval-rmse:14.3373	train-rmse:10.1534
# [420]	eval-rmse:14.3506	train-rmse:10.1506
# [421]	eval-rmse:14.3579	train-rmse:10.1479
# [422]	eval-rmse:14.3573	train-rmse:10.1422
# [423]	eval-rmse:14.3603	train-rmse:10.1374
# [424]	eval-rmse:14.3736	train-rmse:10.1346
# [425]	eval-rmse:14.3762	train-rmse:10.1304
# [426]	eval-rmse:14.3755	train-rmse:10.1248
# [427]	eval-rmse:14.3846	train-rmse:10.1188
# [428]	eval-rmse:14.3977	train-rmse:10.1161
# [429]	eval-rmse:14.4012	train-rmse:10.1143
# [430]	eval-rmse:14.4005	train-rmse:10.1089
# [431]	eval-rmse:14.403	train-rmse:10.1047
# [432]	eval-rmse:14.4159	train-rmse:10.1021
# [433]	eval-rmse:14.4194	train-rmse:10.1004
# [434]	eval-rmse:14.4186	train-rmse:10.095
# [435]	eval-rmse:14.4216	train-rmse:10.0907
# [436]	eval-rmse:14.4344	train-rmse:10.0881
# [437]	eval-rmse:14.4402	train-rmse:10.0856
# [438]	eval-rmse:14.4394	train-rmse:10.0804
# [439]	eval-rmse:14.4403	train-rmse:10.0718
# [440]	eval-rmse:14.453	train-rmse:10.0693
# [441]	eval-rmse:14.4553	train-rmse:10.0653
# [442]	eval-rmse:14.4544	train-rmse:10.0601
# [443]	eval-rmse:14.4631	train-rmse:10.0543
# [444]	eval-rmse:14.4757	train-rmse:10.0518
# [445]	eval-rmse:14.4789	train-rmse:10.0471
# [446]	eval-rmse:14.478	train-rmse:10.0421
# [447]	eval-rmse:14.4789	train-rmse:10.0337
# [448]	eval-rmse:14.4914	train-rmse:10.0312
# [449]	eval-rmse:14.4934	train-rmse:10.0273
# [450]	eval-rmse:14.5058	train-rmse:10.0249
# [451]	eval-rmse:14.5088	train-rmse:10.0233
# [452]	eval-rmse:14.5079	train-rmse:10.0183
# [453]	eval-rmse:14.5109	train-rmse:10.0138
# [454]	eval-rmse:14.5232	train-rmse:10.0114
# [455]	eval-rmse:14.524	train-rmse:10.0031
# [456]	eval-rmse:14.5231	train-rmse:9.99824
# [457]	eval-rmse:14.5249	train-rmse:9.99435
# [458]	eval-rmse:14.537	train-rmse:9.99204
# [459]	eval-rmse:14.5399	train-rmse:9.98798
# [460]	eval-rmse:14.5389	train-rmse:9.98316
# [461]	eval-rmse:14.5441	train-rmse:9.98084
# [462]	eval-rmse:14.5561	train-rmse:9.97858
# [463]	eval-rmse:14.5569	train-rmse:9.97043
# [464]	eval-rmse:14.5559	train-rmse:9.96569
# [465]	eval-rmse:14.5586	train-rmse:9.96128
# [466]	eval-rmse:14.5705	train-rmse:9.95905
# [467]	eval-rmse:14.5732	train-rmse:9.95759
# [468]	eval-rmse:14.5722	train-rmse:9.95293
# [469]	eval-rmse:14.5738	train-rmse:9.94912
# [470]	eval-rmse:14.5856	train-rmse:9.94694
# [471]	eval-rmse:14.5864	train-rmse:9.93891
# [472]	eval-rmse:14.5853	train-rmse:9.93431
# [473]	eval-rmse:14.5877	train-rmse:9.93035
# [474]	eval-rmse:14.5993	train-rmse:9.92821
# [475]	eval-rmse:14.6038	train-rmse:9.91691
# [476]	eval-rmse:14.6064	train-rmse:9.9155
# [477]	eval-rmse:14.6054	train-rmse:9.911
# [478]	eval-rmse:14.6099	train-rmse:9.89988
# [479]	eval-rmse:14.6215	train-rmse:9.89777
# [480]	eval-rmse:14.6229	train-rmse:9.89403
# [481]	eval-rmse:14.6274	train-rmse:9.88307
# [482]	eval-rmse:14.6389	train-rmse:9.88098
# [483]	eval-rmse:14.6413	train-rmse:9.87668
# [484]	eval-rmse:14.6458	train-rmse:9.86586
# [485]	eval-rmse:14.6447	train-rmse:9.8615
# [486]	eval-rmse:14.6494	train-rmse:9.85932
# [487]	eval-rmse:14.6607	train-rmse:9.85727
# [488]	eval-rmse:14.6652	train-rmse:9.84663
# [489]	eval-rmse:14.6765	train-rmse:9.8446
# [490]	eval-rmse:14.6771	train-rmse:9.83667
# [491]	eval-rmse:14.6817	train-rmse:9.83238
# [492]	eval-rmse:14.6861	train-rmse:9.82189
# [493]	eval-rmse:14.6873	train-rmse:9.8182
# [494]	eval-rmse:14.6985	train-rmse:9.81621
# [495]	eval-rmse:14.7029	train-rmse:9.80586
# [496]	eval-rmse:14.7074	train-rmse:9.80166
# [497]	eval-rmse:14.7097	train-rmse:9.80032
# [498]	eval-rmse:14.7141	train-rmse:9.79013
# [499]	eval-rmse:14.7251	train-rmse:9.78816

# %%
plt.figure(figsize=(10, 5))
train_metric = evals_result['train']['rmse']
plt.plot(train_metric, label='train rmse')
eval_metric = evals_result['eval']['rmse']
plt.plot(eval_metric, label='eval rmse')
plt.grid()
plt.legend()
plt.xlabel('rounds')
plt.ylabel('rmse')
plt.ylim(5, 40)
plt.show()

# %%
from sklearn.metrics import mean_squared_error
pred = bst.predict(dvalid)

rmse = np.sqrt(mean_squared_error(Y_train, pred))
print(rmse)
# Out:
# 18.117527764049782

# %%
dtest = xgb.DMatrix(test)
pred = pd.DataFrame()
pred["Id"] = test_index
ans = ((bst.predict(dtest))*2.0).round(0)/2
pred["DBH"] = ans
pred.to_csv("DBH_NonLog.csv", index=False)
